# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure()
plt.plot(range(1,11), [0.63, 0.69, 0.72, 0.73, 0.76, 0.73, 0.77, 0.79, 0.79, 0.78])
plt.axis([1, 10, 0.4, 1.0])
plt.ylabel('Accuracy')
plt.xlabel('Iterations')
plt.show()

plt.figure()
plt.plot(range(1,11), [1.38, 2.49, 3.45, 4.61, 5.42, 6.42, 7.38, 8.35, 9.17, 10.91])
plt.axis([1, 10, 0.0, 11.0])
plt.ylabel('Run Time (seconds)')
plt.xlabel('Iterations')
plt.show()

plt.figure()
plt.plot(range(1,11), [0.73, 0.78, 0.81, 0.82, 0.82, 0.83, 0.83, 0.83, 0.84, 0.83])
plt.axis([1, 10, 0.4, 1.0])
plt.ylabel('Accuracy')
plt.xlabel('Iterations')
plt.show()

plt.figure()
plt.plot(range(1,11), [0.63, 0.69, 0.72, 0.73, 0.76, 0.73, 0.77, 0.79, 0.79, 0.78], range(1,11), [0.73, 0.78, 0.81, 0.82, 0.82, 0.83, 0.83, 0.83, 0.84, 0.83])
plt.axis([1, 10, 0.4, 1.0])
plt.ylabel('Accuracy')
plt.xlabel('Iterations')
plt.show()

# %%
plt.figure()
plt.plot(range(1,5), [0.263, 9.94, 193, 1426])
plt.plot(range(1,11), [0.0338, 9.9, 39.6, 64.6, 84.8, 124, 164, 253, 328, 423])
plt.axis([1, 10, 0, 1500])
plt.ylabel('Time (seconds)')
plt.xlabel('Max Sentence Length')
plt.show()

plt.figure()
plt.plot(range(1,5), [0.857, 0.745, 0.647, 0.697])
plt.plot(range(1,11), [0, 0.588, 0.539, 0.643, 0.565, 0.581, 0.566, 0.592, 0.601, 0.576])
plt.axis([1, 10, 0, 1])
plt.ylabel('Word Accuracy')
plt.xlabel('Max Sentence Length')
plt.show()

plt.figure()
plt.plot(range(1,5), [0.857, 0.666, 0.316, 0.421])
plt.plot(range(1,11), [0, 0.414, 0.225, 0.273, 0.170, 0.128, 0.136, 0.0732, 0.0444, 0.0375])
plt.axis([1, 10, 0, 1])
plt.ylabel('Sentence Accuracy')
plt.xlabel('Max Sentence Length')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.show()

# %%
A = np.array([[1, 2, 3, 4, 5, 6],
              [2, 3, 4, 5, 6, 7]])

plt.plot(A[0,:], A[1,:], 'o')
plt.figure()
plt.plot(A[0],A[1],'o')

# %%
from spacy.en import English
nlp = English()
doc = nlp(u'Hello world. Here are two sentences.')

for i, token in enumerate(doc):
    print("Original:", token.orth_, token.pos_)
    if i > 1:
        break
# Out:
# ('Original:', u'Hello', u'INTJ')
# ('Original:', u'world', u'NOUN')
# ('Original:', u'.', u'PUNCT')
